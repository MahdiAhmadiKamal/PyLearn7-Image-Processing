# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_dice = cv2.imread("input/dice5.png", cv2.IMREAD_GRAYSCALE)
plt.axis("off")
plt.imshow(img_dice, cmap="gray")
plt.show()

# %%
_, img_dice_trsh = cv2.threshold(img_dice, 210, 255, cv2.THRESH_BINARY)
plt.axis("off")
plt.imshow(img_dice_trsh, cmap="gray")
plt.show()

# %%
img_dice_trsh = 255 - img_dice_trsh
plt.axis("off")
plt.imshow(img_dice_trsh, cmap="gray")
plt.show()

# %%
kernel = np.array([[-1 , -1 , -1],
                   [-1 ,  8 , -1],
                   [-1 , -1 , -1]])

img_dice_edge = cv2.filter2D(img_dice_trsh,-1,kernel)
plt.imshow(img_dice_edge, cmap='gray')
plt.show()

# %%
contours, _ = cv2.findContours(img_dice_edge, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
len(contours)
# Out:
# 64

# %%
result = img_dice.copy()

for contour in contours:
    # if cv2.contourArea(contour) > 100:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(result, (x, y), (x+w, y+h), (127, 127, 127), 3)

plt.axis("off")
plt.imshow(result, cmap="gray")
plt.show()

# %%
contours, hierarchy = cv2.findContours(img_dice_edge, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
hierarchy
# Out:
# array([[[12, -1,  1, -1],
#         [-1, -1,  2,  0],
#         [ 4, -1,  3,  1],
#         [-1, -1, -1,  2],
#         [ 6,  2,  5,  1],
#         [-1, -1, -1,  4],
#         [ 8,  4,  7,  1],
#         [-1, -1, -1,  6],
#         [10,  6,  9,  1],
#         [-1, -1, -1,  8],
#         [-1,  8, 11,  1],
#         [-1, -1, -1, 10],
#         [25,  0, 13, -1],
#         [-1, -1, 14, 12],
#         [15, -1, -1, 13],
#         [17, 14, 16, 13],
#         [-1, -1, -1, 15],
#         [19, 15, 18, 13],
#         [-1, -1, -1, 17],
#         [21, 17, 20, 13],
#         [-1, -1, -1, 19],
#         [23, 19, 22, 13],
#         [-1, -1, -1, 21],
#         [-1, 21, 24, 13],
#         [-1, -1, -1, 23],
#         [39, 12, 26, -1],
#         [-1, -1, 27, 25],
#         [29, -1, 28, 26],
#         [-1, -1, -1, 27],
#         [31, 27, 30, 26],
#         [-1, -1, -1, 29],
#         [33, 29, 32, 26],
#         [-1, -1, -1, 31],
#         [35, 31, 34, 26],
#         [-1, -1, -1, 33],
#         [-1, 33, 36, 26],
#         [37, -1, -1, 35],
#         [38, 36, -1, 35],
#         [-1, 37, -1, 35],
#         [51, 25, 40, -1],
#         [-1, -1, 41, 39],
#         [43, -1, 42, 40],
#         [-1, -1, -1, 41],
#         [45, 41, 44, 40],
#         [-1, -1, -1, 43],
#         [47, 43, 46, 40],
#         [-1, -1, -1, 45],
#         [49, 45, 48, 40],
#         [-1, -1, -1, 47],
#         [-1, 47, 50, 40],
#         [-1, -1, -1, 49],
#         [-1, 39, 52, -1],
#         [-1, -1, 53, 51],
#         [55, -1, 54, 52],
#         [-1, -1, -1, 53],
#         [57, 53, 56, 52],
#         [-1, -1, -1, 55],
#         [59, 55, 58, 52],
#         [-1, -1, -1, 57],
#         [62, 57, 60, 52],
#         [61, -1, -1, 59],
#         [-1, 60, -1, 59],
#         [-1, 59, 63, 52],
#         [-1, -1, -1, 62]]], dtype=int32)
