# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_dice = cv2.imread("input/dice5.png", cv2.IMREAD_GRAYSCALE)
plt.axis("off")
plt.imshow(img_dice, cmap="gray")
plt.show()

# %%
_, img_dice_trsh = cv2.threshold(img_dice, 210, 255, cv2.THRESH_BINARY)
plt.axis("off")
plt.imshow(img_dice_trsh, cmap="gray")
plt.show()

# %%
img_dice_trsh = 255 - img_dice_trsh
plt.axis("off")
plt.imshow(img_dice_trsh, cmap="gray")
plt.show()

# %%
contours, _ = cv2.findContours(img_dice_trsh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
len(contours)
# Out:
# 34

# %%
result = img_dice.copy()

for contour in contours:
    # if cv2.contourArea(contour) > 100:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(result, (x, y), (x+w, y+h), (127, 127, 127), 3)

plt.axis("off")
plt.imshow(result, cmap="gray")
plt.show()

# %%
contours, hierarchy = cv2.findContours(img_dice_gray_trsh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
hierarchy
# Out:
# array([[[ 1, -1, -1, -1],
#         [ 4,  0,  2, -1],
#         [ 3, -1, -1,  1],
#         [-1,  2, -1,  1],
#         [ 5,  1, -1, -1],
#         [ 6,  4, -1, -1],
#         [ 7,  5, -1, -1],
#         [ 8,  6, -1, -1],
#         [-1,  7,  9, -1],
#         [-1, -1, -1,  8]]], dtype=int32)
